# %% [markdown]
# # Submitting a RBFE Alchemiscale

# %%
from alchemiscale import AlchemiscaleClient, Scope

# %%
asc = AlchemiscaleClient(
    "https://api.alchemiscale.org",
)
# Credentials are autodetected here

# %% [markdown]
# ## Exploring Scopes

# %%
openff_scope = asc.list_scopes()[1]
asc.list_scopes()
# Out:
# [<Scope('omsf-*-*')>, <Scope('openff-*-*')>]

# %%
asc.query_networks(scope=Scope("openff"))
# Out:
# [<ScopedKey('AlchemicalNetwork-330f4422697b3f1035915299495a0ca0-openff-sage_2_0_0-problematic_phosphates')>,
#  <ScopedKey('AlchemicalNetwork-6e027c8753c4e0ba84ddebf79b32d4f6-openff-openff_2_0_0-minisolv')>,
#  <ScopedKey('AlchemicalNetwork-6e29c051ccb626e6854a33d8ad059fce-openff-openff_2_0_0-freesolv')>,
#  <ScopedKey('AlchemicalNetwork-899765f52259bffb4dbd4ddf1d56e97f-openff-openff_2_2_1_oe-mnsol')>,
#  <ScopedKey('AlchemicalNetwork-b3df252b28bbecdfa9364bf2eee76b40-openff-openff_2_2_1_oe-freesolv')>,
#  <ScopedKey('AlchemicalNetwork-03491e7d092475e24f9771cc43b00449-openff-openff_2_2_1_ambertools-freesolv')>,
#  <ScopedKey('AlchemicalNetwork-e291b945ffb3938b1fcf42ab83187cf8-openff-openff_2_2_1_ambertools-mnsol')>,
#  <ScopedKey('AlchemicalNetwork-e5bc6aeb94b18a8202cafbe84f20ef00-openff-openff_2_2_1_nagl-freesolv')>,
#  <ScopedKey('AlchemicalNetwork-195ca0c26fe2b890f07ab1f0ec748bcc-openff-openff_2_2_1_nagl-mnsol')>,
#  <ScopedKey('AlchemicalNetwork-b181e1d253170a6fd9b0cf617e82faf3-openff-openff_2_2_1_ambertools-highrmse')>,
#  <ScopedKey('AlchemicalNetwork-72ca289045134ec1edb5f7bb1224cc90-openff-openff_2_2_1_oe-highrmse')>,
#  <ScopedKey('AlchemicalNetwork-500df6115d516157099dcf8e0629fc7f-openff-openff_2_2_1_ambertools-highrmse')>,
#  <ScopedKey('AlchemicalNetwork-146f351c8b144eaeded5a45ca008a465-openff-openff_2_2_1_oe-highrmse')>,
#  <ScopedKey('AlchemicalNetwork-f64feff274af517b161ebacfbf1e0072-openff-openff_2_3_0_rc1-freesolv')>,
#  <ScopedKey('AlchemicalNetwork-1c6299355b83701c98763d50cae19d62-openff-openff_2_3_0_rc1-mnsol')>,
#  <ScopedKey('AlchemicalNetwork-665f37978a37f80629a968fd3fb0af35-openff-openff_2_3_0_rc1-freesolv')>,
#  <ScopedKey('AlchemicalNetwork-64708c4557e4df7a96c90b3ce9a23019-openff-openff_2_3_0_rc1-mnsol')>,
#  <ScopedKey('AlchemicalNetwork-be47c7a076288eff09fc38944ccaaf90-openff-openff_2_3_0_rc1-highrmse')>,
#  <ScopedKey('AlchemicalNetwork-518a69101fba8b29bbb6fbb6b0ba9a5d-openff-openff_2_3_0_rc1-freesolv')>,
#  <ScopedKey('AlchemicalNetwork-1da8a109fced0b44bca6a9889265a40f-openff-openff_2_3_0_rc1-mnsol')>,
#  <ScopedKey('AlchemicalNetwork-d85da4210348005b4cfc3e9105d28b88-openff-openff_2_3_0_rc1-highrmse')>,
#  <ScopedKey('AlchemicalNetwork-4ad8868dbde2b206d8f78276d0074267-openff-openff_2_3_0_v2-mnsol')>,
#  <ScopedKey('AlchemicalNetwork-ba0d4a6110f9c5dffd20d5f56503a7f4-openff-openff_2_3_0_v2-freesolv')>,
#  <ScopedKey('AlchemicalNetwork-43f153b23fdeea64f2bdb8e8577f482b-openff-openff_2_3_0_v2-mnsol')>,
#  <ScopedKey('AlchemicalNetwork-812c531b45a56c1f3f6eb36f3ffafc62-openff-openff_2_3_0_v2-freesolv')>,
#  <ScopedKey('AlchemicalNetwork-4658a7b78f097b40e6436b54be6706e3-openff-fb_fit_v2_single_mean_k100-mnsol')>,
#  <ScopedKey('AlchemicalNetwork-2f0b107e732b6e4ef8340876359a5105-openff-fb_fit_v2_single_mean_k100-freesolv')>,
#  <ScopedKey('AlchemicalNetwork-5cd9eb805fe5c425ebca1714832eddc4-openff-fb_fit_v1_single_mean_k100-mnsol')>,
#  <ScopedKey('AlchemicalNetwork-72175bafbb4aae7a0e93d3f93789e9bc-openff-fb_fit_v1_single_mean_k100-freesolv')>,
#  <ScopedKey('AlchemicalNetwork-8d7296e3292581590b3154ad375f68d9-openff-fb_fit_v3_single_mean_k100-mnsol')>,
#  <ScopedKey('AlchemicalNetwork-8c5ce6c98960313fb25dceadae3666f7-openff-fb_fit_v3_single_mean_k100-freesolv')>,
#  <ScopedKey('AlchemicalNetwork-866d0bb6e4c1eacdf7d92524570a52ce-openff-fb_fit_v0_single_mean_k20-mnsol')>,
#  <ScopedKey('AlchemicalNetwork-e3f485b8a2d9db3c5b7f55a6cf4be648-openff-fb_fit_v0_single_mean_k20-freesolv')>,
#  <ScopedKey('AlchemicalNetwork-5c393885b9be537d626fe635ea7687d7-openff-fb_fit_v3_single_mean_k20-mnsol')>,
#  <ScopedKey('AlchemicalNetwork-8a3c5fc7b0dffeba1b51653378d026b1-openff-fit_iter_1-mnsol')>,
#  <ScopedKey('AlchemicalNetwork-fb9a4671ac20b5f894cec17481d3d36a-openff-vdw_refit-mnsol')>,
#  <ScopedKey('AlchemicalNetwork-23c90ee82e96cbc375abba37c84257b3-openff-vdw_refit-freesolv')>,
#  <ScopedKey('AlchemicalNetwork-e6ad9f99368b898bf877e4d38e2b2d22-openff-openff_230_rc2-freesolv')>,
#  <ScopedKey('AlchemicalNetwork-d8dfeecccb55b47304d332b01133140a-openff-openff_221-freesolv')>,
#  <ScopedKey('AlchemicalNetwork-2dd5d032b0228c7474eda50d8e064c2d-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('AlchemicalNetwork-ca248d3033cc83ec1b91f35b4173e1f5-openff-openff_2_3_0_release-freesolv')>,
#  <ScopedKey('AlchemicalNetwork-55961080ba1805b112aff83fca84b15f-openff-openff_2_3_0_release-freesolv')>]

# %%
# Retrieve network
an_sk = asc.query_networks(scope=Scope("openff"))[0]
network2 = asc.get_network(an_sk)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ## Executing Our Network

# %%
# %%script false --no-raise-error
#
# # Now make your own scope and submit a network,
# # RUNNING MULTIPLE TIMES WILL CREATE MULTIPLE REPLICATES ON ALCHEMISCALE
# network = openfe.AlchemicalNetwork.from_json(file="alchemical_network_jacs_set_tyk2.json")
# scope = Scope('openff', 'test', 'openff_2_3_0_tyk2')
# an_sk = asc.create_network(network, scope)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
# %%script false --no-raise-error
an_sk = (
    "AlchemicalNetwork-2dd5d032b0228c7474eda50d8e064c2d-openff-test-openff_2_3_0_tyk2"
)

tf_sks = asc.get_network_transformations(an_sk)
tasks = asc.create_transformations_tasks(tf_sks * 2)
print(f"There are {len(tasks)} tasks")

# Now we need to action the tasks before they can be picked up for compute
asc.action_tasks(tasks, an_sk)
# Out:
# There are 88 tasks
# [<ScopedKey('Task-7294c3de0fab4889b97c9c4d1fa59747-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-2907a6ba40e14a9c8769703749e84f01-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-008b4c22283a4c63b73d4e26be4c34d6-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-2cca2f3762954eeba9ac06e1033d27a2-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-bd87180e46cc4ee2a601c13e40857a76-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-d66693f02c0745ab8e67924da5b54ddf-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-26f3235e5be849a69b54417f836c16ec-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-8e609df11b2f4f8b92c1a7c2e1c9ab4c-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-42d7ccbae29a407e973a2ac1b5bf0aa6-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-2b45b8d566d1490fb28c064acc25eb82-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-1de0d436a70943c0b2fde9fb14509e9b-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-8dfe224b736145878edb68fd487e0a8d-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-80d4ad1db534473d81dea43e2459b5c2-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-581fc0506be8415db66208c9010b18a8-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-e467b8b188cb4c78974b4ebfebad7636-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-d208a6c654694de58f9e4684857c0980-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-22467bb088c84effaed167d83d629fcb-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-3480e97c422a4eb493393952abec840a-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-083ff50c0b0b4896a9fdd21f9649fabc-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-216c8fbe9ae4458eb88463676a2b8a48-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-d8bae9a623164ef7875402eb42094a1e-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-b69e5bec7c584f2f9f4bbfeb0101f531-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-77ab7bee0d984851bb4d899e868b7c3d-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-5659d7e68133470a9e93b410011ca198-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-06159a0a8fd74b53967767411fe24b53-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-467fde5dd2f147e5a99095fc7fe5986b-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-37ce6c0652714d3bafd760ecdc845075-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-18bd47157f6c43e4a102d1d96c51dd1c-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-c4d453ec42f944388e26c95aec02d1f7-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-d40b2e97a2eb4c88b133c712f587796d-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-a56aa8c5de2348e6ac25c058d4691f76-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-730e4ec5acce4ede8bea72f3d1e83ddf-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-1a5131a10c0b4dfba27f84f22889752e-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-963206a9c89e469787d650b9027f4754-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-62df7e5f224b46f0bfb86eabb5ed0a00-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-866b65ee95e847299c8bc11549c91fe4-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-a52f9ffa9f6143158aed937a540ece6e-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-eb9a8ad8e87e4d3db58916996f282140-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-0c38aa23abf045d995e5165a43fa3724-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-6a268ee83b584a688147e3f63ca51287-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-533ca33082d54bb78bc83ec4b34538b1-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-d450c7047be24d2997ed3da3baa8e7c5-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-8464038c3c104119b7513c0fec35938e-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-cc8ae7c04f8b47769d4b8c1e31bfc106-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-952dc4344ff74115a4b9f892263c3445-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-fcf6bcb725c141b994f71a80a1369e6a-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-69e6f0d846ab4ffb87598921a44aeb49-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-01e17fd1b07a4d1abe542c5400f60722-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-228c6364b93940b7844c5ea0e7964810-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-c365e188e89c48a3a61cbdc9342d1265-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-b730350a523f41c1843af0da9f188da7-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-0c6155bc462443fd9788faeca132c813-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-41f71e98eb4842699f422dc8c62e3614-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-b7474bd6930644cd8710bdd8c9e6e3ca-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-dc1b538dbe754c92a4bad549b5aef371-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-2906dc66d93640138c9f3cef4951f33b-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-5b2a17b3a93d46e39e7baca9f666eace-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-0915e2fde964415bac8a82ab8e704be8-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-785a1aa377dd4022a86546c5b37d933a-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-02019a16f0fc4d8680143f52113b0f09-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-98f9962d28274e9bad007231b1356b96-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-2a6c281dd2a44e17a5e84e08128068cd-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-e85907aea9cf4f48a24e0ac1c9e2de3d-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-f384730324b84efc97694dcecef43d96-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-3432de86ba1440a1833569797473f0fe-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-7a0e2d7108e54fbda3024d2293af7ceb-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-932197e38a1c449dbef919a9a5c9cc05-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-50664aca767444d498cbdd348a6655e6-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-9e3554de0a80465d812d21e83fcc53f5-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-aab12a07edff42a89a63389295a736b9-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-2919dc2089184d86a2964ba408ba8879-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-540504e3ca8346ef850a930eab4388e1-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-29f6d4157cb547819649265bc5774a09-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-88f7867d589a470c8356be6a0db8d85c-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-a5a70a6a5a0c4b51bd1a63e3da6dabe0-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-7e78cb87af3746188239b8ce595fd5da-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-d3704d881baa4485a7c1e2c9a2a5d0c2-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-25046d59db3c4136bc75195f0c0e67fa-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-dfa1ceeeb00544b79b0858a1d6537a66-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-a0cf70124a7546e39c185878a1c44de4-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-6a631be252b24994b3e6c9137167181b-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-cb794853f485487e9302dfc1b26f76e0-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-310feee94a2e4147a0a1decafca25ba4-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-ebf82c0d9db54d4cb6c58b289c0e1ff9-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-899463f9ca634ae4a86e8ce3b38d1305-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-678a66dd64754715a3a385803d4cc477-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-e85a0744182349d09d47c44127c4e3f2-openff-test-openff_2_3_0_tyk2')>,
#  <ScopedKey('Task-92bb46a4e1384d849e6a638fbf102c9e-openff-test-openff_2_3_0_tyk2')>]

# %%
an_sk = (
    "AlchemicalNetwork-2dd5d032b0228c7474eda50d8e064c2d-openff-test-openff_2_3_0_tyk2"
)
asc.get_network_status(an_sk)
# Out:
# AlchemicalNetwork-2dd5d032b0228c7474eda50d8e064c2d-openff-test-openff_2_3_0_tyk2
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ status                                                           ┃                                        count ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ complete                                                         │                                          132 │
# │ running                                                          │                                            0 │
# │ waiting                                                          │                                            0 │
# │ error                                                            │                                            0 │
# │ invalid                                                          │                                            0 │
# │ deleted                                                          │                                            0 │
# └──────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────┘
# {'complete': 132}

# %% [markdown]
# ## Checking Results

# %%
asc.get_network_status(an_sk)

# %%
failed_tasks = asc.get_network_tasks(an_sk, status="error")
failures = asc.get_task_failures(failed_tasks[0])
failures

# %%
print(failures[0].protocol_unit_failures[0].traceback)

# %%
# asc.set_tasks_status(failed_tasks[:1], 'waiting')

# %% [markdown]
# # Gather and Download Results
